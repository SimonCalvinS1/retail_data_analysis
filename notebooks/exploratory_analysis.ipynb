# %% [markdown]
# ## Module imports:

# %%
import pandas as pd

# %% [markdown]
# ## Data Cleaning

# %%
df = pd.read_excel('../data/retail_dataset.xlsx')

# Fix unclean data: (State -> [Region, City])
state_geography_map = {
    'Andhra Pradesh': ['South', 'Hyderabad'],
    'Bihar': ['East', 'Patna'],
    'Chhattisgarh': ['Central', 'Bhopal'], 
    'Delhi': ['North', 'Delhi'],
    'Goa': ['West', 'Panaji'],
    'Gujarat': ['West', 'Ahmedabad'],
    'Haryana': ['North', 'Chandigarh'],
    'Himachal Pradesh': ['North', 'Shimla'],
    'Jharkhand': ['East', 'Ranchi'],
    'Karnataka': ['South', 'Bangalore'],
    'Kerala': ['South', 'Kochi'],
    'Madhya Pradesh': ['Central', 'Bhopal'],
    'Maharashtra': ['West', 'Mumbai'],
    'Odisha': ['East', 'Bhubaneswar'],
    'Punjab': ['North', 'Chandigarh'],
    'Rajasthan': ['North', 'Jaipur'],
    'Tamil Nadu': ['South', 'Chennai'],
    'Telangana': ['South', 'Hyderabad'],
    'Uttar Pradesh': ['North', 'Lucknow'],
    'West Bengal': ['East', 'Kolkata']
}

def fix_data(row):
    state = row['State']
    if state in state_geography_map:
        row['region'] = state_geography_map[state][0]
        row['City'] = state_geography_map[state][1]
    return row

df = df.apply(fix_data, axis=1)

df['invoice_date'] = pd.to_datetime(df['invoice_date']).dt.date

df.columns = df.columns.str.strip()

df.to_excel('../data/retail_dataset_cleaned.xlsx', index=False)
print("Data Cleaned and Saved to 'retail_dataset_cleaned.xlsx'")
# Out:
# Data Cleaned and Saved to 'retail_dataset_cleaned.xlsx'

# %% [markdown]
# ## Basic information regarding the dataset:

# %%
df = pd.read_excel('../data/retail_dataset_cleaned.xlsx')

print("Head of the DataFrame:")
print(df.head())
# Out:
# Head of the DataFrame:
#     retailer retailer_id invoice_date   region           State        City  \
# 0  HyperCity     RET1520   2024-01-31    North         Haryana  Chandigarh
# 1  HyperCity     RET4611   2025-04-04  Central    Chhattisgarh      Bhopal
# 2    Grofers     RET3547   2024-08-08     East     West Bengal     Kolkata
# 3      DMart     RET8527   2025-07-03    North   Uttar Pradesh     Lucknow
# 4     Amazon     RET2139   2024-02-16    South  Andhra Pradesh   Hyderabad
#
#       product  price_per_unit  units_sold  total_sales  operating_profit  \
# 0    Notebook          304.99         292        89057             11905
# 1        Milk          381.82          86        32836              8816
# 2  Toothpaste           57.39         438        25136              4345
# 3         Pen          153.66         326        50093             12373
# 4         Oil          434.58         199        86481             13409
#
#    operating_margin sales_method
# 0            0.1337    Wholesale
# 1            0.2685          App
# 2            0.1729          App
# 3            0.2470          App
# 4            0.1551          App

# %%
print("DataFrame Info:")
print(df.info())
# Out:
# DataFrame Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   retailer          1199 non-null   str
#  1   retailer_id       1199 non-null   str
#  2   invoice_date      1199 non-null   datetime64[us]
#  3   region            1199 non-null   str
#  4   State             1199 non-null   str
#  5   City              1199 non-null   str
#  6   product           1199 non-null   str
#  7   price_per_unit    1199 non-null   float64
#  8   units_sold        1199 non-null   int64
#  9   total_sales       1199 non-null   int64
#  10  operating_profit  1199 non-null   int64
#  11  operating_margin  1199 non-null   float64
#  12  sales_method      1199 non-null   str
# dtypes: datetime64[us](1), float64(2), int64(3), str(7)
# memory usage: 121.9 KB
# None

# %%
print(f"Dataframe statistics: ")
print(df.describe().round(2))
# Out:
# Dataframe statistics:
#                      invoice_date  price_per_unit  units_sold  total_sales  \
# count                        1199         1199.00     1199.00      1199.00
# mean   2024-12-28 22:38:19.916597          252.93      260.30     66663.36
# min           2024-01-01 00:00:00           10.41        5.00       373.00
# 25%           2024-06-23 12:00:00          126.95      139.00     19345.00
# 50%           2024-12-29 00:00:00          247.75      257.00     48312.00
# 75%           2025-07-10 12:00:00          379.69      390.00    105172.50
# max           2025-12-31 00:00:00          499.73      500.00    233207.00
# std                           NaN          142.66      143.96     57531.29
#
#        operating_profit  operating_margin
# count           1199.00           1199.00
# mean           14629.71              0.22
# min               88.00              0.08
# 25%             3791.00              0.15
# 50%            10001.00              0.22
# 75%            22100.50              0.28
# max            75861.00              0.35
# std            14289.47              0.08

# %%
print(f"Dataset shape: {df.shape}") # Count of rows and columns
# Out:
# Dataset shape: (1199, 13)

# %%
print("Missing Values:")
print(df.isnull().sum()) # Count of missing values in each column in the dataframe
# Out:
# Missing Values:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# State               0
# City                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# operating_margin    0
# sales_method        0
# dtype: int64

# %% [markdown]
# ## Statistical information about the dataset

# %%
print("Top 5 most expensive products: ")
print(df.sort_values(by = 'price_per_unit', ascending = False).head(5)[['product', 'price_per_unit']])

print("\nTop 5 least expensive products: ")
print(df.sort_values(by = 'price_per_unit').head(5)[['product', 'price_per_unit']])
# Out:
# Top 5 most expensive products:
#        product  price_per_unit
# 902    Chicken          499.73
# 1102   Chicken          499.73
# 1047       Pen          499.02
# 847        Pen          499.02
# 492   Biscuits          499.00
#
# Top 5 least expensive products:
#      product  price_per_unit
# 587     Milk           10.41
# 1004    Milk           10.49
# 804     Milk           10.49
# 39      Soap           10.83
# 302    Chips           11.26

# %% [markdown]
# ## Count of Cities and States

# %%
print("\nPlaces by State (Top 5):")
print(df['State'].value_counts().head(5))
print("\n" + "-" * 50)
print("\nPlaces by City (Top 15):")
print(df['City'].value_counts().head(15))
# Out:
# Places by State (Top 5):
# State
# Madhya Pradesh    81
# Chhattisgarh      79
# Haryana           69
# Rajasthan         69
# Uttar Pradesh     68
# Name: count, dtype: int64
#
# --------------------------------------------------
#
# Places by City (Top 15):
# City
# Bhopal         160
# Hyderabad      121
# Chandigarh     111
# Jaipur          69
# Lucknow         68
# Bangalore       68
# Patna           66
# Kolkata         65
# Shimla          63
# Kochi           58
# Bhubaneswar     55
# Ahmedabad       55
# Chennai         55
# Ranchi          52
# Panaji          46
# Name: count, dtype: int64
